# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from utils.methods import *

# %%
# Read file csv
data = pd.read_csv("../../Dataset/dseb63_final_project_DP_dataset/dseb63_bureau_balance.csv")
data.head(30)
# Out:
#     SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 0        5715448               0      C
# 1        5715448              -1      C
# 2        5715448              -2      C
# 3        5715448              -3      C
# 4        5715448              -4      C
# 5        5715448              -5      C
# 6        5715448              -6      C
# 7        5715448              -7      C
# 8        5715448              -8      C
# 9        5715448              -9      0
# 10       5715448             -10      0
# 11       5715448             -11      X
# 12       5715448             -12      X
# 13       5715448             -13      X
# 14       5715448             -14      0
# 15       5715448             -15      0
# 16       5715448             -16      0
# 17       5715448             -17      0
# 18       5715448             -18      0
# 19       5715448             -19      0
# 20       5715448             -20      X
# 21       5715448             -21      X
# 22       5715448             -22      X
# 23       5715448             -23      X
# 24       5715448             -24      X
# 25       5715448             -25      X
# 26       5715448             -26      X
# 27       5715449               0      C
# 28       5715449              -1      C
# 29       5715449              -2      C

# %%
data.shape
# Out:
# (27299925, 3)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27299925 entries, 0 to 27299924
# Data columns (total 3 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   SK_ID_BUREAU    int64
#  1   MONTHS_BALANCE  int64
#  2   STATUS          object
# dtypes: int64(2), object(1)
# memory usage: 624.8+ MB

# %%
#total number of duplicate rows in bureau balance's column
data.duplicated().sum()
# Out:
# 0

# %%
# The number of unique elements in each column
data.nunique()
# Out:
# SK_ID_BUREAU      817395
# MONTHS_BALANCE        97
# STATUS                 8
# dtype: int64

# %%
# Count the number of each type of STATUS
data['STATUS'].value_counts()
# Out:
# STATUS
# C    13646993
# 0     7499507
# X     5810482
# 1      242347
# 5       62406
# 2       23419
# 3        8924
# 4        5847
# Name: count, dtype: int64

# %%
# Total missing data and the percentage of missing values in each column
def missing_data(data):
    total = data.isnull().sum().sort_values(ascending = False)
    percent = (data.isnull().sum()/data.isnull().count()*100).sort_values(ascending = False)
    return pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])

# %%
missing_data(data)
# Out:
#                 Total  Percent
# SK_ID_BUREAU        0      0.0
# MONTHS_BALANCE      0      0.0
# STATUS              0      0.0

# %%
# Wanted palette details
new_palette = ['#EB0524', 'grey', '#B0041D', 'black']
color_codes_wanted = ['C1', 'C2', 'C3', 'C4']
c = lambda x: enmax_palette[color_codes_wanted.index(x)]

# %% [markdown]
# **MERGE with TARGET columns in application_train.csv**

# %%
bureau = pd.read_csv("../../Dataset/dseb63_final_project_DP_dataset/dseb63_bureau.csv")
bureau.head()
# Out:
#    SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 0       5714462        Closed      currency 1         -497
# 1       5714463        Active      currency 1         -208
# 2       5714464        Active      currency 1         -203
# 3       5714465        Active      currency 1         -203
# 4       5714466        Active      currency 1         -629
#
#    CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 0                   0               -153.0             -153.0
# 1                   0               1075.0                NaN
# 2                   0                528.0                NaN
# 3                   0                  NaN                NaN
# 4                   0               1197.0                NaN
#
#    AMT_CREDIT_MAX_OVERDUE  CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  \
# 0                     NaN                   0         91323.0
# 1                     NaN                   0        225000.0
# 2                     NaN                   0        464323.5
# 3                     NaN                   0         90000.0
# 4                 77674.5                   0       2700000.0
#
#    AMT_CREDIT_SUM_DEBT  AMT_CREDIT_SUM_LIMIT  AMT_CREDIT_SUM_OVERDUE  \
# 0                  0.0                   NaN                     0.0
# 1             171342.0                   NaN                     0.0
# 2                  NaN                   NaN                     0.0
# 3                  NaN                   NaN                     0.0
# 4                  NaN                   NaN                     0.0
#
#        CREDIT_TYPE  DAYS_CREDIT_UPDATE  AMT_ANNUITY  SK_ID_CURR
# 0  Consumer credit                -131          NaN      254629
# 1      Credit card                 -20          NaN      254629
# 2  Consumer credit                 -16          NaN      254629
# 3      Credit card                 -16          NaN      254629
# 4  Consumer credit                 -21          NaN      254629

# %%
# Import SK_ID_CURR and TARGET column from application_train
target = pd.read_csv("../../Dataset/dseb63_final_project_DP_dataset/dseb63_application_train.csv", usecols = ['TARGET', 'SK_ID_CURR'])
target.head()
# Out:
#    TARGET  SK_ID_CURR
# 0       0      278621
# 1       0      139008
# 2       0      138348
# 3       0       64140
# 4       0      219374

# %%
# Merge SK_ID_BUREAU with SK_ID_CURR in bureau.csv
data_merged_prev = pd.merge(bureau[['SK_ID_CURR','SK_ID_BUREAU']], data, how= 'left', on=['SK_ID_BUREAU'])
data_merged_prev.head()
# Out:
#    SK_ID_CURR  SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 0      254629       5714462             NaN    NaN
# 1      254629       5714463             NaN    NaN
# 2      254629       5714464             NaN    NaN
# 3      254629       5714465             NaN    NaN
# 4      254629       5714466             NaN    NaN

# %%
# Merge SK_ID_CURR with target
data_merged = pd.merge(target, data_merged_prev, how='left', on=['SK_ID_CURR'])
data_merged.head()
# Out:
#    TARGET  SK_ID_CURR  SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 0       0      278621     5885877.0             NaN    NaN
# 1       0      278621     5885878.0             NaN    NaN
# 2       0      278621     5885879.0             NaN    NaN
# 3       0      278621     5885880.0             NaN    NaN
# 4       0      139008           NaN             NaN    NaN

# %% [markdown]
# MONTHS_BALANCE

# %%
# Check when the oldest data recorded for each customer
grouped = data.groupby('SK_ID_BUREAU').MONTHS_BALANCE.min().reset_index()
grouped
# Out:
#         SK_ID_BUREAU  MONTHS_BALANCE
# 0            5001709             -96
# 1            5001710             -82
# 2            5001711              -3
# 3            5001712             -18
# 4            5001713             -21
# ...              ...             ...
# 817390       6842884             -47
# 817391       6842885             -23
# 817392       6842886             -32
# 817393       6842887             -36
# 817394       6842888             -61
#
# [817395 rows x 2 columns]

# %%
grouped['MONTHS_BALANCE'].describe()
# Out:
# count    817395.000000
# mean        -39.432847
# std          28.132570
# min         -96.000000
# 25%         -58.000000
# 50%         -34.000000
# 75%         -16.000000
# max           0.000000
# Name: MONTHS_BALANCE, dtype: float64

# %% [markdown]
# On average, this file contains data about the balance of credit bureaus for 39 months. The number of bureau credit that have data is 817395

# %%
# MONTHS_BALANCE analysis
plot_continuous_variables(data_merged, 'MONTHS_BALANCE', plots=['distplot','box'], figsize=(20,10))

# %% [markdown]
# Both defaulters and non-defaulters have MONTHS_BALANCE distributed mainly over a period of < 20 days. With MONTHS_BALANCE <-20, non-defaulter has greater density than defaulter. Mean is also larger than defaulter (length of credit history is large -> more likely to be non-defaulter).

# %% [markdown]
# STATUS

# %%
# STATUS analysis
plot_categorical_bar_vertical(data_merged,'STATUS',rotation=80, horizontal_adjust=0.25)
# Out:
# Total Number of unique categories of STATUS = 9

# %% [markdown]
# Defaulter more usually repay their loan overdue than Non-Defaulter

# %% [markdown]
# Number of STATUS for each customer

# %%
# Calculate the number of unique STATUS values for each combination of SK_ID_CURR and TARGET
grp = data_merged[['SK_ID_CURR', 'STATUS', 'TARGET']].groupby(['SK_ID_CURR','TARGET'])['STATUS'].nunique().reset_index()
grp
# Out:
#         SK_ID_CURR  TARGET  STATUS
# 0                0       0       0
# 1                1       1       2
# 2                2       0       0
# 3                3       0       0
# 4                4       0       0
# ...            ...     ...     ...
# 246004      307505       0       2
# 246005      307506       0       0
# 246006      307507       0       0
# 246007      307509       0       3
# 246008      307510       0       0
#
# [246009 rows x 3 columns]

# %%
# STATUS analysis
plot_continuous_variables(grp,'STATUS', plots = ['distplot','box'],figsize=(20,10))

# %% [markdown]
# It can be said that the number of STATUS does not affect whether customers have difficulty repaying debt or not because the distribution is very similar.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from utils.methods import *
warnings.filterwarnings('ignore')

# %%
pos = pd.read_csv('../../Dataset/dseb63_final_project_DP_dataset/dseb63_POS_CASH_balance.csv')
pos.head()
# Out:
#    SK_ID_PREV  MONTHS_BALANCE  CNT_INSTALMENT  CNT_INSTALMENT_FUTURE  \
# 0     1803195             -31            48.0                   45.0
# 1     1803195             -17            48.0                   31.0
# 2     1803195             -21            48.0                   35.0
# 3     1803195              -8            48.0                   21.0
# 4     1803195              -4            48.0                   17.0
#
#   NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF  SK_ID_CURR
# 0               Active       0           0      185279
# 1               Active       0           0      185279
# 2               Active       0           0      185279
# 3               Active       0           0      185279
# 4               Active       0           0      185279

# %%
pos.shape
# Out:
# (8543375, 8)

# %%
pos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8543375 entries, 0 to 8543374
# Data columns (total 8 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   SK_ID_PREV             int64
#  1   MONTHS_BALANCE         int64
#  2   CNT_INSTALMENT         float64
#  3   CNT_INSTALMENT_FUTURE  float64
#  4   NAME_CONTRACT_STATUS   object
#  5   SK_DPD                 int64
#  6   SK_DPD_DEF             int64
#  7   SK_ID_CURR             int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 521.4+ MB

# %%
pos.duplicated().sum()
# Out:
# 0

# %%
def check_missed_values(df):
    df_null_percentage = df.isnull().sum() / df.shape[0] * 100
    df_null_percentage = df_null_percentage.drop(df_null_percentage[df_null_percentage == 0].index).sort_values(ascending= False).reset_index()
    df_null_percentage.columns = ["Feature", "Percentage"]
    return df_null_percentage

null_df = check_missed_values(pos)

# %%
plt.figure(figsize=(16,5))
sns.barplot(x=  null_df["Percentage"] , y= null_df["Feature"] )
# Out:
# <Axes: xlabel='Percentage', ylabel='Feature'>

# %%
stat = StatisticAnalysis(pos)
stat.correlation()

# %% [markdown]
# CNT_INSTALMENT_FUTURE and CNT_INSTALMENT are highly correlated

# %% [markdown]
# **Univariate Analysis**

# %%
univariate = UnivariateAnalysis(pos)

# %% [markdown]
# Numeric features

# %%
num_cols = [c for c in pos.columns if c not in ['NAME_CONTRACT_STATUS', 'SK_ID_PREV', 'SK_ID_CURR']]
num_cols
# Out:
# ['MONTHS_BALANCE',
#  'CNT_INSTALMENT',
#  'CNT_INSTALMENT_FUTURE',
#  'SK_DPD',
#  'SK_DPD_DEF']

# %%
for c in num_cols:
    print(c)
    univariate.visualize_numeric(x=c, kde=True)
# Out:
# MONTHS_BALANCE
# count    8.543375e+06
# mean    -3.494812e+01
# std      2.605372e+01
# min     -9.600000e+01
# 25%     -5.400000e+01
# 50%     -2.800000e+01
# 75%     -1.300000e+01
# max     -1.000000e+00
# Name: MONTHS_BALANCE, dtype: float64
# CNT_INSTALMENT
# count    8.521512e+06
# mean     1.703348e+01
# std      1.200430e+01
# min      1.000000e+00
# 25%      1.000000e+01
# 50%      1.200000e+01
# 75%      2.400000e+01
# max      8.400000e+01
# Name: CNT_INSTALMENT, dtype: float64
# CNT_INSTALMENT_FUTURE
# count    8.521497e+06
# mean     1.046808e+01
# std      1.114408e+01
# min      0.000000e+00
# 25%      3.000000e+00
# 50%      7.000000e+00
# 75%      1.400000e+01
# max      8.400000e+01
# Name: CNT_INSTALMENT_FUTURE, dtype: float64
# SK_DPD
# count    8.543375e+06
# mean     1.190473e+01
# std      1.340302e+02
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      4.231000e+03
# Name: SK_DPD, dtype: float64
# SK_DPD_DEF
# count    8.543375e+06
# mean     5.835209e-01
# std      3.042110e+01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      3.373000e+03
# Name: SK_DPD_DEF, dtype: float64

# %% [markdown]
# Categorical feature

# %% [markdown]
# NAME_CONTRACT_STATUS

# %%
univariate.visualize('NAME_CONTRACT_STATUS', rotate=60, create_other=True)

# %% [markdown]
# Almost all the customers contract status is Active. Around 7% is completed and the small porportion are for the remain status

# %% [markdown]
# **Bivariate Analysis**

# %%
curr = pd.read_csv('../../Dataset/dseb63_final_project_DP_dataset/dseb63_application_train.csv')
pos_merged = pd.merge(curr[['SK_ID_CURR', 'TARGET']], pos, how='left', on='SK_ID_CURR')
pos_merged
# Out:
#          SK_ID_CURR  TARGET  SK_ID_PREV  MONTHS_BALANCE  CNT_INSTALMENT  \
# 0            278621       0   2396755.0           -66.0            12.0
# 1            278621       0   2636178.0           -23.0             6.0
# 2            278621       0   1810518.0           -23.0            12.0
# 3            278621       0   1810518.0           -25.0            12.0
# 4            278621       0   2396755.0           -67.0            12.0
# ...             ...     ...         ...             ...             ...
# 6848110      258328       0   1743609.0           -28.0            12.0
# 6848111      258328       0   1743609.0           -32.0            12.0
# 6848112      258328       0   1359084.0           -10.0            12.0
# 6848113      258328       0   1743609.0           -25.0            12.0
# 6848114      258328       0   1359084.0            -8.0            12.0
#
#          CNT_INSTALMENT_FUTURE NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF
# 0                          1.0               Active     0.0         0.0
# 1                          1.0               Active     0.0         0.0
# 2                         10.0               Active     0.0         0.0
# 3                         12.0               Active     0.0         0.0
# 4                          2.0               Active     0.0         0.0
# ...                        ...                  ...     ...         ...
# 6848110                    7.0               Active     0.0         0.0
# 6848111                   11.0               Active     0.0         0.0
# 6848112                    7.0               Active     0.0         0.0
# 6848113                    4.0               Active     5.0         5.0
# 6848114                    5.0               Active     0.0         0.0
#
# [6848115 rows x 9 columns]

# %%
bia = BivariateAnalysis()

# %%
for c in num_cols:
    print(c)
    bia.box_plot(y=c, data_to_plot=pos_merged)
# Out:
# MONTHS_BALANCE
# CNT_INSTALMENT
# CNT_INSTALMENT_FUTURE
# SK_DPD
# SK_DPD_DEF

# %% [markdown]
# - According to the boxplots, Defaulters tend to have shorter MONTH_BALANCES compare to Non-defaulter. Which means they seems to make loan more frequently.
# - Defaulters also have higher CNT_INSTALMENT_FUTURE (Installments left to pay on the previous credit) than Non - defaulters

# %%
## get the most recent record of each customer
pos_filter = pos.sort_values(by=['MONTHS_BALANCE']).groupby(['SK_ID_PREV', 'SK_ID_CURR'], as_index=False).last()
pos_filter
# Out:
#         SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  CNT_INSTALMENT  \
# 0          1000001      117953              -8             2.0
# 1          1000003        6707              -1            12.0
# 2          1000004      187620             -22             7.0
# 3          1000005       83759             -46            10.0
# 4          1000007       25033              -1             6.0
# ...            ...         ...             ...             ...
# 800332     2843494       70155             -24             2.0
# 800333     2843495      274857              -9             7.0
# 800334     2843497       50590              -1            24.0
# 800335     2843498       12906             -42             6.0
# 800336     2843499      237534             -30            10.0
#
#         CNT_INSTALMENT_FUTURE NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF
# 0                         0.0            Completed       0           0
# 1                         9.0               Active       0           0
# 2                         0.0            Completed       0           0
# 3                         0.0            Completed       0           0
# 4                         2.0               Active       0           0
# ...                       ...                  ...     ...         ...
# 800332                    0.0            Completed       0           0
# 800333                    0.0            Completed       0           0
# 800334                    4.0               Active       0           0
# 800335                    0.0            Completed       0           0
# 800336                    0.0            Completed       0           0
#
# [800337 rows x 8 columns]

# %%
pos_filter.duplicated(subset=['SK_ID_CURR']).sum()
# Out:
# 510893

# %%
pos_filter['FLAG_COMPLETED'] = pos_filter['NAME_CONTRACT_STATUS'].apply(lambda x: 1 if x == 'Completed' else 0)
pos_filter['NFLAG_COMPLETED'] = pos_filter.groupby(['SK_ID_CURR'])['FLAG_COMPLETED'].transform('sum')
pos_filter.drop(columns=['FLAG_COMPLETED'], inplace=True)
pos_filter
# Out:
#         SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  CNT_INSTALMENT  \
# 0          1000001      117953              -8             2.0
# 1          1000003        6707              -1            12.0
# 2          1000004      187620             -22             7.0
# 3          1000005       83759             -46            10.0
# 4          1000007       25033              -1             6.0
# ...            ...         ...             ...             ...
# 800332     2843494       70155             -24             2.0
# 800333     2843495      274857              -9             7.0
# 800334     2843497       50590              -1            24.0
# 800335     2843498       12906             -42             6.0
# 800336     2843499      237534             -30            10.0
#
#         CNT_INSTALMENT_FUTURE NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF  \
# 0                         0.0            Completed       0           0
# 1                         9.0               Active       0           0
# 2                         0.0            Completed       0           0
# 3                         0.0            Completed       0           0
# 4                         2.0               Active       0           0
# ...                       ...                  ...     ...         ...
# 800332                    0.0            Completed       0           0
# 800333                    0.0            Completed       0           0
# 800334                    4.0               Active       0           0
# 800335                    0.0            Completed       0           0
# 800336                    0.0            Completed       0           0
#
#         NFLAG_COMPLETED
# 0                     1
# 1                     1
# 2                     7
# 3                     1
# 4                     1
# ...                 ...
# 800332                3
# 800333                3
# 800334                6
# 800335                8
# 800336                4
#
# [800337 rows x 9 columns]

# %%
nflag_completed_group = pos_filter.groupby(['NFLAG_COMPLETED']).size()
nflag_completed_group
# Out:
# NFLAG_COMPLETED
# 0      38228
# 1     157471
# 2     176327
# 3     144492
# 4     103603
# 5      68800
# 6      43431
# 7      26995
# 8      16475
# 9       9683
# 10      5776
# 11      3369
# 12      2277
# 13      1235
# 14       836
# 15       525
# 16       335
# 17       190
# 18       158
# 19        19
# 20        41
# 21        45
# 24        26
# dtype: int64

# %%
# Get the indices of the three highest values
top3_indices = nflag_completed_group.nlargest(3).index

# Define a custom palette with red for the top 3 values and grey with decreased alpha for others
custom_palette = ['red' if i in top3_indices else (0.7, 0.7, 0.7, 0.5) for i in nflag_completed_group.index]

# Create the bar plot with the custom palette
fig, ax = plt.subplots(figsize=(15, 6))
sns.barplot(x=list(nflag_completed_group.index), y=list(nflag_completed_group.values), palette=custom_palette, ax=ax)
ax.set_title('Number of customers complete most recent contract')
plt.show()

# %% [markdown]
# - Most of the customers complete 2 payments, follows by 1 and 3 payments
# - The higher the number of the payments, the lower the number of customers can complete it

# %% [markdown]
# PAST DUE

# %%
def pastdue_flag(x):
    if x['SK_DPD_DEF'] > 0 and x['CNT_INSTALMENT_FUTURE'] > 0:
        return 1
    else:
        return 0

pos_filter['FLAG_PASTDUE'] = pos_filter.apply(pastdue_flag, axis= 1)
pos_filter
# Out:
#         SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  CNT_INSTALMENT  \
# 0          1000001      117953              -8             2.0
# 1          1000003        6707              -1            12.0
# 2          1000004      187620             -22             7.0
# 3          1000005       83759             -46            10.0
# 4          1000007       25033              -1             6.0
# ...            ...         ...             ...             ...
# 800332     2843494       70155             -24             2.0
# 800333     2843495      274857              -9             7.0
# 800334     2843497       50590              -1            24.0
# 800335     2843498       12906             -42             6.0
# 800336     2843499      237534             -30            10.0
#
#         CNT_INSTALMENT_FUTURE NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF  \
# 0                         0.0            Completed       0           0
# 1                         9.0               Active       0           0
# 2                         0.0            Completed       0           0
# 3                         0.0            Completed       0           0
# 4                         2.0               Active       0           0
# ...                       ...                  ...     ...         ...
# 800332                    0.0            Completed       0           0
# 800333                    0.0            Completed       0           0
# 800334                    4.0               Active       0           0
# 800335                    0.0            Completed       0           0
# 800336                    0.0            Completed       0           0
#
#         NFLAG_COMPLETED  FLAG_PASTDUE
# 0                     1             0
# 1                     1             0
# 2                     7             0
# 3                     1             0
# 4                     1             0
# ...                 ...           ...
# 800332                3             0
# 800333                3             0
# 800334                6             0
# 800335                8             0
# 800336                4             0
#
# [800337 rows x 10 columns]

# %%
pos_filter['NFLAG_PASTDUE'] = pos_filter.groupby(['SK_ID_CURR'])['FLAG_PASTDUE'].transform('sum')
pos_filter.drop(columns=['FLAG_PASTDUE'], inplace=True)
pos_filter
# Out:
#         SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  CNT_INSTALMENT  \
# 0          1000001      117953              -8             2.0
# 1          1000003        6707              -1            12.0
# 2          1000004      187620             -22             7.0
# 3          1000005       83759             -46            10.0
# 4          1000007       25033              -1             6.0
# ...            ...         ...             ...             ...
# 800332     2843494       70155             -24             2.0
# 800333     2843495      274857              -9             7.0
# 800334     2843497       50590              -1            24.0
# 800335     2843498       12906             -42             6.0
# 800336     2843499      237534             -30            10.0
#
#         CNT_INSTALMENT_FUTURE NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF  \
# 0                         0.0            Completed       0           0
# 1                         9.0               Active       0           0
# 2                         0.0            Completed       0           0
# 3                         0.0            Completed       0           0
# 4                         2.0               Active       0           0
# ...                       ...                  ...     ...         ...
# 800332                    0.0            Completed       0           0
# 800333                    0.0            Completed       0           0
# 800334                    4.0               Active       0           0
# 800335                    0.0            Completed       0           0
# 800336                    0.0            Completed       0           0
#
#         NFLAG_COMPLETED  NFLAG_PASTDUE
# 0                     1              0
# 1                     1              0
# 2                     7              0
# 3                     1              0
# 4                     1              0
# ...                 ...            ...
# 800332                3              0
# 800333                3              0
# 800334                6              0
# 800335                8              0
# 800336                4              0
#
# [800337 rows x 10 columns]

# %%
nflag_pastdue_group = pos_filter.groupby(['NFLAG_PASTDUE']).size()[1:]
nflag_pastdue_group
# Out:
# NFLAG_PASTDUE
# 1    4472
# 2     431
# 3     110
# 4      16
# dtype: int64

# %%
# Get the index of the highest value
max_index = nflag_pastdue_group.idxmax()

# Define a custom palette with red for the highest value and grey with varying alpha for others
custom_palette = ['red' if i == max_index else (0.7, 0.7, 0.7, 0.3 + 0.2 * (nflag_pastdue_group[i] / nflag_pastdue_group[max_index])) for i in nflag_pastdue_group.index]

# Create the bar plot with the custom palette
fig, ax = plt.subplots(figsize=(10, 6))
sns.barplot(x=list(nflag_pastdue_group.index), y=list(nflag_pastdue_group.values), palette=custom_palette, ax=ax)
ax.set_title('Number of customers past due')
plt.show()
